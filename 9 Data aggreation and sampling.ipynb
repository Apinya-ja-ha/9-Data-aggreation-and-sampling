# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('obama.csv', parse_dates=['year_month'])
data.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
plt.plot(data.year_month, data.approve_percent, 'o', markersize=2, alpha=0.3)
plt.show()

# %%
data.groupby('year_month').mean()
# Out:
#             approve_percent  disapprove_percent
# year_month
# 2009-01-01        67.307692           19.346154
# 2009-02-01        61.500000           26.289474
# 2009-03-01        57.842105           34.026316
# 2009-04-01        59.282609           33.195652
# 2009-05-01        58.966667           34.900000
# 2009-06-01        56.916667           36.277778
# 2009-07-01        53.130435           40.000000
# 2009-08-01        50.473684           42.815789
# 2009-09-01        51.214286           43.285714
# 2009-10-01        51.083333           43.583333
# 2009-11-01        49.166667           45.566667
# 2009-12-01        46.300000           47.875000
# 2010-01-01        46.642857           47.642857
# 2010-02-01        46.157895           47.868421
# 2010-03-01        45.157895           49.078947
# 2010-04-01        46.657895           48.184211
# 2010-05-01        47.000000           46.718750
# 2010-06-01        45.388889           48.333333
# 2010-07-01        44.647059           49.264706
# 2010-08-01        43.900000           49.475000
# 2010-09-01        45.823529           48.617647
# 2010-10-01        45.050000           48.750000
# 2010-11-01        44.916667           49.708333
# 2010-12-01        43.666667           49.750000
# 2011-01-01        48.588235           45.705882
# 2011-02-01        47.666667           46.166667
# 2011-03-01        46.000000           46.952381
# 2011-04-01        44.093750           50.250000
# 2011-05-01        49.000000           44.868421
# 2011-06-01        45.888889           47.722222
# ...                     ...                 ...
# 2014-08-01        41.222222           52.722222
# 2014-09-01        40.166667           53.750000
# 2014-10-01        39.857143           54.392857
# 2014-11-01        41.428571           53.214286
# 2014-12-01        42.500000           53.090909
# 2015-01-01        44.366667           49.233333
# 2015-02-01        42.458333           51.583333
# 2015-03-01        43.214286           50.964286
# 2015-04-01        44.285714           50.214286
# 2015-05-01        44.285714           50.071429
# 2015-06-01        44.000000           51.269231
# 2015-07-01        43.125000           50.800000
# 2015-08-01        42.333333           52.458333
# 2015-09-01        43.675000           50.800000
# 2015-10-01        43.750000           51.295455
# 2015-11-01        41.911765           52.264706
# 2015-12-01        41.684211           52.789474
# 2016-01-01        45.000000           49.531250
# 2016-02-01        44.833333           50.111111
# 2016-03-01        48.142857           47.119048
# 2016-04-01        47.566667           47.533333
# 2016-05-01        48.071429           47.607143
# 2016-06-01        48.694444           46.416667
# 2016-07-01        49.222222           46.611111
# 2016-08-01        50.078947           45.473684
# 2016-09-01        49.738095           46.952381
# 2016-10-01        51.583333           45.111111
# 2016-11-01        51.900000           43.466667
# 2016-12-01        52.038462           42.153846
# 2017-01-01        55.266667           40.533333
#
# [97 rows x 2 columns]

# %%
data_mean=data.groupby('year_month').mean()
plt.plot(data_mean.index,  data_mean.approve_percent, 'red')
plt.show()

# %%
data_mean=data.groupby('year_month').mean()
plt.plot(data_mean.index,  data_mean.approve_percent, 'red')
plt.plot(data.year_month, data.approve_percent, 'o', markersize=2, alpha=0.3)
plt.show()

# %%
data_mean=data.groupby('year_month').mean()
data_median=data.groupby('year_month').median()

plt.plot(data_mean.index,  data_mean.approve_percent, 'red')
plt.plot(data_median.index, data_median.approve_percent, 'green')
plt.legend(['Mean','Median'])

plt.plot(data.year_month, data.approve_percent, 'o', markersize=2, alpha=0.3)

plt.show()

# %%
data_25=data.groupby('year_month').quantile(0.25)
data_75=data.groupby('year_month').quantile(0.75)

plt.plot(data_75.index, data_75.approve_percent, 'green')
plt.plot(data_median.index, data_median.approve_percent,'red')
plt.plot(data_25.index, data_25.approve_percent, 'blue')
plt.plot(data.year_month, data.approve_percent, 'o',markersize=2, alpha=0.3)

plt.legend(['75th Percentile', 'Median', '25th Percentile'])
plt.show()
